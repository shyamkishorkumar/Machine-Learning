# %% [markdown]
# ### Importing all the required Libraries

# %%
import pandas as pd

# %% [markdown]
# ### Display all the rows in Jupter Notebook
# ### Display all the columns in Jupter Notebook

# %%
pd.reset_option("display.max_rows",None)

# %% [markdown]
# ### Reading the dataset

# %%
fish_toxicity_df = pd.read_csv("../Data/qsar_fish_toxicity.csv", sep=";", header=None)
fish_toxicity_df.head()
# Out:
#        0      1      2  3  4      5      6
# 0  3.260  0.829  1.676  0  1  1.453  3.770
# 1  2.189  0.580  0.863  0  0  1.348  3.115
# 2  2.125  0.638  0.831  0  0  1.348  3.531
# 3  3.027  0.331  1.472  1  0  1.807  3.510
# 4  2.094  0.827  0.860  0  0  1.886  5.390

# %% [markdown]
# ### Checking the Column names in a dataframe

# %%
list(fish_toxicity_df.columns)
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### Renaming Columns

# %%
fish_toxicity_df.rename(columns={0:'Col1', 1:'Col2', 2:'Col3', 3:'Col4', 4:'Col5', 5:'Col6', 6:'Target'}, inplace=True)
fish_toxicity_df.head()
# Out:
#     Col1   Col2   Col3  Col4  Col5   Col6  Target
# 0  3.260  0.829  1.676     0     1  1.453   3.770
# 1  2.189  0.580  0.863     0     0  1.348   3.115
# 2  2.125  0.638  0.831     0     0  1.348   3.531
# 3  3.027  0.331  1.472     1     0  1.807   3.510
# 4  2.094  0.827  0.860     0     0  1.886   5.390

# %% [markdown]
# ### Rename all Columns in one shot

# %%
# Example 1
fish_toxicity_df.rename(str.lower, axis='columns').head()
# Out:
#     col1   col2   col3  col4  col5   col6  target
# 0  3.260  0.829  1.676     0     1  1.453   3.770
# 1  2.189  0.580  0.863     0     0  1.348   3.115
# 2  2.125  0.638  0.831     0     0  1.348   3.531
# 3  3.027  0.331  1.472     1     0  1.807   3.510
# 4  2.094  0.827  0.860     0     0  1.886   5.390

# %%
# Example 2
fish_toxicity_df.rename(lambda x : x.upper(), axis='columns').head()
# Out:
#     COL1   COL2   COL3  COL4  COL5   COL6  TARGET
# 0  3.260  0.829  1.676     0     1  1.453   3.770
# 1  2.189  0.580  0.863     0     0  1.348   3.115
# 2  2.125  0.638  0.831     0     0  1.348   3.531
# 3  3.027  0.331  1.472     1     0  1.807   3.510
# 4  2.094  0.827  0.860     0     0  1.886   5.390

# %%
# Example 3
fish_toxicity_df.rename(lambda X : X.capitalize(), axis='columns').head()
# Out:
#     Col1   Col2   Col3  Col4  Col5   Col6  Target
# 0  3.260  0.829  1.676     0     1  1.453   3.770
# 1  2.189  0.580  0.863     0     0  1.348   3.115
# 2  2.125  0.638  0.831     0     0  1.348   3.531
# 3  3.027  0.331  1.472     1     0  1.807   3.510
# 4  2.094  0.827  0.860     0     0  1.886   5.390

# %%
# Example 4
fish_toxicity_df.rename(lambda x : x.replace('l','L'), axis='columns').head()
# Out:
#     CoL1   CoL2   CoL3  CoL4  CoL5   CoL6  Target
# 0  3.260  0.829  1.676     0     1  1.453   3.770
# 1  2.189  0.580  0.863     0     0  1.348   3.115
# 2  2.125  0.638  0.831     0     0  1.348   3.531
# 3  3.027  0.331  1.472     1     0  1.807   3.510
# 4  2.094  0.827  0.860     0     0  1.886   5.390

# %% [markdown]
# ### Check the shape of the data frame

# %%
fish_toxicity_df.shape
# Out:
# (908, 7)

# %% [markdown]
# ### Number of rows in the dataframe

# %%
len(fish_toxicity_df)
# Out:
# 908

# %% [markdown]
# ### Description of the dataframe

# %%
fish_toxicity_df.describe()
# Out:
#              Col1        Col2        Col3        Col4        Col5        Col6  \
# count  908.000000  908.000000  908.000000  908.000000  908.000000  908.000000
# mean     2.898129    0.628468    1.293591    0.229075    0.485683    2.109285
# std      0.756088    0.428459    0.394303    0.605335    0.861279    1.433181
# min      0.667000    0.000000    0.396000    0.000000    0.000000   -2.884000
# 25%      2.347000    0.223000    0.950750    0.000000    0.000000    1.209000
# 50%      2.934000    0.570000    1.240500    0.000000    0.000000    2.127000
# 75%      3.407000    0.892750    1.562250    0.000000    1.000000    3.105000
# max      5.926000    2.171000    2.920000    4.000000    6.000000    6.515000
#
#            Target
# count  908.000000
# mean     4.064431
# std      1.455698
# min      0.053000
# 25%      3.151750
# 50%      3.987500
# 75%      4.907500
# max      9.612000

# %% [markdown]
# ### Information of the dataset.

# %%
fish_toxicity_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908 entries, 0 to 907
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Col1    908 non-null    float64
#  1   Col2    908 non-null    float64
#  2   Col3    908 non-null    float64
#  3   Col4    908 non-null    int64
#  4   Col5    908 non-null    int64
#  5   Col6    908 non-null    float64
#  6   Target  908 non-null    float64
# dtypes: float64(5), int64(2)
# memory usage: 49.8 KB

# %% [markdown]
# ### Sum of NAs in each column / Count Nas in each columns

# %%
fish_toxicity_df.isna().sum()
# Out:
# Col1      0
# Col2      0
# Col3      0
# Col4      0
# Col5      0
# Col6      0
# Target    0
# dtype: int64

# %% [markdown]
# ### Checking the datatype of each column

# %%
fish_toxicity_df.dtypes
# Out:
# Col1      float64
# Col2      float64
# Col3      float64
# Col4        int64
# Col5        int64
# Col6      float64
# Target    float64
# dtype: object

# %% [markdown]
# ### Changing the datatype of a specific column

# %%
fish_toxicity_df['Col1'] = fish_toxicity_df['Col1'].astype('float16')
fish_toxicity_df.dtypes
# Out:
# Col1      float16
# Col2      float64
# Col3      float64
# Col4        int64
# Col5        int64
# Col6      float64
# Target    float64
# dtype: object

# %% [markdown]
# ### View Unique values

# %%
## Mostly used for categorical columns
# unique_values = fish_toxicity_df['Col3'].unique()
display(list(unique_values))
len_unique_values = len(unique_values)
print(len_unique_values)
# Out:
# [1.676,
#  0.863,
#  0.831,
#  1.472,
#  0.86,
#  2.177,
#  1.063,
#  0.938,
#  0.99,
#  0.95,
#  0.843,
#  0.953,
#  0.929,
#  1.237,
#  1.271,
#  1.114,
#  1.322,
#  1.781,
#  2.698,
#  1.205,
#  1.889,
#  1.103,
#  0.923,
#  0.96,
#  0.724,
#  0.986,
#  1.294,
#  1.984,
#  2.128,
#  0.954,
#  0.865,
#  1.155,
#  2.135,
#  1.519,
#  1.179,
#  1.11,
#  1.248,
#  1.15,
#  0.944,
#  1.522,
#  1.599,
#  1.0,
#  0.92,
#  1.344,
#  1.17,
#  1.933,
#  1.851,
#  1.023,
#  1.627,
#  1.678,
#  1.45,
#  1.374,
#  0.771,
#  0.764,
#  0.899,
#  0.839,
#  0.838,
#  0.917,
#  1.609,
#  1.695,
#  1.537,
#  1.333,
#  1.468,
#  1.891,
#  1.844,
#  1.758,
#  1.445,
#  1.13,
#  1.361,
#  1.946,
#  1.429,
#  1.068,
#  1.878,
#  1.5,
#  1.605,
#  1.581,
#  2.259,
#  1.671,
#  1.527,
#  1.6,
#  1.907,
#  1.066,
#  1.69,
#  1.583,
#  1.869,
#  0.814,
#  1.987,
#  0.895,
#  0.836,
#  1.293,
#  0.907,
#  1.385,
#  0.857,
#  1.478,
#  2.261,
#  1.959,
#  1.717,
#  1.559,
#  1.328,
#  1.529,
#  1.684,
# ...

# %% [markdown]
# ### Unique value count // Number of unique values

# %%
fish_toxicity_df['Col3'].nunique()
# Out:
# 557

# %% [markdown]
# ### Number of occurance of every item.
# #### Mostly used for categorical variables

# %%
fish_toxicity_df['Col3'].value_counts()
# Out:
# Col3
# 0.941    8
# 1.179    7
# 0.871    7
# 0.954    7
# 0.938    7
#         ..
# 1.700    1
# 1.563    1
# 1.481    1
# 2.095    1
# 1.183    1
# Name: count, Length: 557, dtype: int64

# %% [markdown]
# ### Returns 5 elemets after sorting the columns 'Target' in descending order

# %%
fish_toxicity_df.nlargest(5,'Target')
# Out:
#          Col1   Col2   Col3  Col4  Col5   Col6  Target
# 259  4.785156  1.263  1.471     1     4  2.749   9.612
# 680  4.218750  1.033  0.963     0     1  4.246   9.354
# 889  4.210938  0.932  1.045     0     1  4.832   8.916
# 663  3.828125  1.259  0.966     1     2  4.279   8.604
# 363  4.535156  0.560  1.137     1     2  4.332   8.571

# %% [markdown]
# ### Drop a column from a dataframe

# %%
fish_toxicity_df.drop(columns=['Col1','Col2']).head()
# Out:
#     Col3  Col4  Col5   Col6  Target
# 0  1.676     0     1  1.453   3.770
# 1  0.863     0     0  1.348   3.115
# 2  0.831     0     0  1.348   3.531
# 3  1.472     1     0  1.807   3.510
# 4  0.860     0     0  1.886   5.390

# %% [markdown]
# ### Drop a row from a dataframe

# %%
fish_toxicity_df.drop(index=[0,1,2]).head()
# Out:
#        Col1   Col2   Col3  Col4  Col5   Col6  Target
# 3  3.027344  0.331  1.472     1     0  1.807   3.510
# 4  2.093750  0.827  0.860     0     0  1.886   5.390
# 5  3.222656  0.331  2.177     0     0  0.706   1.819
# 6  3.179688  0.000  1.063     0     0  2.942   3.947
# 7  3.000000  0.000  0.938     1     0  2.851   3.513

# %% [markdown]
# ### Display Options / Show All rows in a dataframe

# %%
# pd.set_option('display.max_rows',None)
# pd.set_option('display.max_columns',None)

# %% [markdown]
# ### Data Extraction

# %% [markdown]
# #### 1. Dot Notation : Can select only a single column

# %%
fish_toxicity_df.Col1.head()
# Out:
# 0    3.259766
# 1    2.189453
# 2    2.125000
# 3    3.027344
# 4    2.093750
# Name: Col1, dtype: float16

# %%
type(fish_toxicity_df.Col1)
# Out:
# pandas.core.series.Series

# %%
(fish_toxicity_df.Col1 > 10 ).head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Col1, dtype: bool

# %%
(fish_toxicity_df.Col2 > 10 ).head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Col2, dtype: bool

# %%
fish_toxicity_df.head()
# Out:
#        Col1   Col2   Col3  Col4  Col5   Col6  Target
# 0  3.259766  0.829  1.676     0     1  1.453   3.770
# 1  2.189453  0.580  0.863     0     0  1.348   3.115
# 2  2.125000  0.638  0.831     0     0  1.348   3.531
# 3  3.027344  0.331  1.472     1     0  1.807   3.510
# 4  2.093750  0.827  0.860     0     0  1.886   5.390
